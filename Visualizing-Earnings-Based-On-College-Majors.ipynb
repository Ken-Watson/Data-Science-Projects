# %% [markdown]
# ## Job Outcomes of College Graduates

# %% [markdown]
# ### This project explores the pandas plotting functionality along with with the Jupyter notebook interface to explore data quickly using visualization. The dataset is on the job outcomes of students who graduated from college between 2010 - 2012 and was released by American Community Survey.
#
# ### Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more.

# %% [markdown]
# #### Import libraries then read the dataset into the dataframe to explore data.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
print(recent_grads.describe())
# print(recent_grads)
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# #### Drop rows with missing values and recount.

# %%
raw_data_count = recent_grads.shape
print(raw_data_count)
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape
print(cleaned_data_count)
# Out:
# (173, 21)
# (172, 21)

# %% [markdown]
# ### Create scatter plots to explore the following relations:
#
# #### Sample Size vs. Median Salaries
#
# From looking at the different sample sizes, the median salary range for larger sample sizes tend to be between 35,000 and 50,000. The salary range for smaller samples varies quite a bit.

# %%
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Sample_size vs. Median')

# %% [markdown]
# #### Sample Size vs. Unemployment Rate
# With larger sample sizes, the unemployment rate tends stay consistent between 0.05 and 0.10.

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Sample_size vs. Unemployment_rate')

# %% [markdown]
# #### Full-Time vs. Median
#
# With the increase in sample sizes of graduates that were full-time students, the salaries tend to stay between 35,000 and 50,000.

# %%
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Full_time vs. Median')

# %% [markdown]
# #### Share of Female Graduates vs. Unemployment Rate
#
# There does not look to be any relation between the share of female graduates and unemployment.

# %%
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('ShareWomen vs. Unemployment_rate')

# %% [markdown]
# #### Male Graduates vs. Median Salary
#
# With the increase in sample sizes of male graduates, the salaries tend to stay between 35,000 and 60,000.

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Men vs. Median')

# %% [markdown]
# #### Female Graduates vs. Median Salary
#
# With the increase in sample sizes of female graduates, the salaries tend to stay between 35,000 and 50,000.

# %%
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax.set_title('Women vs. Median')

# %% [markdown]
# ### Create histograms to explore the distributions of the following:
#
# #### Sample Size
#
# The histogram shows the distribution of sample sizes drops off significantly after the first 1,000 graduates.

# %%
ax = recent_grads['Sample_size'].hist(bins=10, range=(0,5000), grid=False)
ax.set_title('Sample_size')

# %% [markdown]
# #### Median Salary
#
# The median salary looks to be between 30,000 and 40,000.

# %%
ax = recent_grads['Median'].hist(bins=10, range=(0,130000), grid=False)
ax.set_title('Median')

# %% [markdown]
# #### Graduates Employed
#
# This shows that there are more certain major categories that have more graduates employed.

# %%
ax = recent_grads['Employed'].hist(bins=10, range=(0,400000), grid=False)
ax.set_title('Employed')

# %% [markdown]
# #### Graduates That Were In School Full-Time
#
# There are certain major categories that have more graduates that went to school full-time.

# %%
ax = recent_grads['Full_time'].hist(bins=10, range=(0,300000), grid=False)
ax.set_title('Full_time')

# %% [markdown]
# #### Share of Women Graduates
#
# The highest share of women as a total of all major categories is between 0.7 and 0.8.

# %%
ax = recent_grads['ShareWomen'].hist(bins=10, grid=False)
ax.set_title('ShareWomen')

# %% [markdown]
# #### Unemployment Rate
#
# The highest rate of unemployment as a total of all major categories is between 0.6 and 0.8.

# %%
ax = recent_grads['Unemployment_rate'].hist(bins=9, grid=False)
ax.set_title('Unemployment_rate')

# %% [markdown]
# #### Male Graduates
#
# This shows that there are certain major categories that had more male graduates.

# %%
ax = recent_grads['Men'].hist(bins=9, grid=False)
ax.set_title('Men')

# %% [markdown]
# #### Female Graduates
#
# This shows that there are certain major categories that had more female graduates.

# %%
ax = recent_grads['Women'].hist(bins=9, grid=False)
ax.set_title('Women')

# %% [markdown]
# ### Combining both scatter plots and histograms into one grid of plots to explore potential relationships and distributions simultaneously.

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(2, 2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8f69d38f28>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8f69bc0390>,
# ...
#       dtype=object)

# %% [markdown]
# ### Creating bar plots to compare the percentages of women from the first 10 rows and last 10 rows.

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %% [markdown]
# ### Creating bar plots to compare the unemployment rate from the first 10 rows and last 10 rows.

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
